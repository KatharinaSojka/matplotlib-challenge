# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# Study Overview:
# The purpose of this study was to compare the performance of Pymaceuticals’ drug of interest, Capomulin, in comparison to other treatment regimens. The study involved 249 mice, with equal distribution among male (51%) and female (49%) subjects. Over a span of 45 days, tumors were observed and measured in the mice every 5 days.
#
# Summary:
#
# 1.	Mice Population: The study included a total of 249 mice, with a balanced distribution of sexes.
#
# 3.	Mice on Capomulin and Ramicate regime: Final tumor volume was significantly lower in mice on Capomulin and Ramicane regime. In both cases average tumor volume [mm3] was ca. 40 mm3; lower variance and standard error score (compared to others)  indicate additionally that  the sample date is less dispersed and closer to the population mean. This indicates the potential efficacy of Capomulin and Ramicane in reducing tumor size with consistency.
# 4.	Impact of Weigh on Tumor size: Pearson correlation test (score of 0.84) revealed a strong correlation between mice weight and tumor volume.
#
# Conclusion:
#
# Overall, the study highlights the promising efficacy of Capomulin and Ramicane regimens in reducing tumor size in mice with squamous cell carcinoma. Additionally, the strong correlation between weight and tumor volume underscores the need to consider weight as a potential factor in treatment outcomes and disease progression.
#
# ---

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st



# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
study_data_complete = pd.merge(study_results, mouse_metadata, how="left", on=["Mouse ID","Mouse ID"])

# Display the data table for preview
study_data_complete
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        f932          0           45.000000                 0     Ketapril
# 2        g107          0           45.000000                 0     Ketapril
# 3        a457          0           45.000000                 0     Ketapril
# 4        c819          0           45.000000                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1888     r944         45           41.581521                 2    Capomulin
# 1889     u364         45           31.023923                 3    Capomulin
# 1890     p438         45           61.433892                 1     Ceftamin
# 1891     x773         45           58.634971                 4      Placebo
# 1892     b879         45           72.555239                 2     Stelasyn
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice.
number_mice = len(study_data_complete["Mouse ID"].unique())
number_mice
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
#duplicate_mice = study_data_complete[study_data_complete["Mouse ID"].duplicated()].values
#duplicate_mice

duplicate_mice = study_data_complete[study_data_complete.duplicated(subset=['Mouse ID', 'Timepoint'], keep=False)]['Mouse ID'].unique()

print(duplicate_mice)
# Out:
# ['g989']

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicated_mice_df = study_data_complete.loc[study_data_complete['Mouse ID'].isin(duplicate_mice)]
duplicated_mice_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
study_data_clean = study_data_complete[~study_data_complete['Mouse ID'].isin(duplicate_mice)]
study_data_clean
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        f932          0           45.000000                 0     Ketapril
# 2        g107          0           45.000000                 0     Ketapril
# 3        a457          0           45.000000                 0     Ketapril
# 4        c819          0           45.000000                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1888     r944         45           41.581521                 2    Capomulin
# 1889     u364         45           31.023923                 3    Capomulin
# 1890     p438         45           61.433892                 1     Ceftamin
# 1891     x773         45           58.634971                 4      Placebo
# 1892     b879         45           72.555239                 2     Stelasyn
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice in the clean DataFrame.
number_mice = len(study_data_clean["Mouse ID"].unique())
number_mice
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen


# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.

mean = study_data_clean.groupby(["Drug Regimen"])["Tumor Volume (mm3)"].mean()
median = study_data_clean.groupby(["Drug Regimen"])["Tumor Volume (mm3)"].median()
variance = study_data_clean.groupby(["Drug Regimen"])["Tumor Volume (mm3)"].var()
std = study_data_clean.groupby(["Drug Regimen"])["Tumor Volume (mm3)"].std()
sem = study_data_clean.groupby(["Drug Regimen"])["Tumor Volume (mm3)"].sem()

statistics = pd.DataFrame({"mean":mean, "median": median, "variance": variance, "std": std, "sem": sem})
statistics
# Out:
#                    mean     median   variance       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line 
study_data_clean_stats = study_data_clean.groupby("Drug Regimen").agg({"Tumor Volume (mm3)": ["mean", "median", "var", "std", st.sem]})

study_data_clean_stats
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
observation_data = study_data_clean["Drug Regimen"].value_counts()
observation_data
# Out:
# Drug Regimen
# Capomulin    230
# Ramicane     228
# Ketapril     188
# Naftisol     186
# Zoniferol    182
# Stelasyn     181
# Placebo      181
# Infubinol    178
# Ceftamin     178
# Propriva     148
# Name: count, dtype: int64

# %%
#configuring plot, figsize, title, axis labels
figure1 = observation_data.plot(kind="bar", color ="#3366FF", alpha=0.9, figsize=(7,5),
                           xlabel="Drug Regimen",
                           ylabel="# of Observed Mouse Timepoints")
xticklabels = observation_data.index
figure1.set_xticklabels(xticklabels, rotation = 90, rotation_mode="anchor",ha="right", wrap=True)
# show plot
plt.show()

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.

x_axis = np.arange(len(observation_data))
y_axis = observation_data

plt.bar(x_axis, y_axis, color ="#3366FF", alpha=0.9, align = "center")
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, observation_data.index, rotation = "vertical")
plt.xlabel("Drug Regimen")
plt.ylabel("# of Observed Mouse Timepoints")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
mouse_sex = study_data_complete["Sex"].value_counts()
mouse_sex
# Out:
# Sex
# Male      958
# Female    935
# Name: count, dtype: int64

# %%
#plotting a pie chart

figure2 = mouse_sex.plot(kind="pie", y= mouse_sex, autopct="%1.0f%%")
figure2.set_ylabel("Sex")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
labels = mouse_sex.index
sex_counts = mouse_sex
plt.pie(mouse_sex, labels=mouse_sex.index, autopct="%1.0f%%")
plt.title("Sex", loc="left", y=0.5, rotation=90, verticalalignment='center', horizontalalignment='center')
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
last_timepoint = study_data_clean.groupby("Mouse ID")["Timepoint"].max()


# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
tumor_last_timepoint = pd.merge(last_timepoint, study_data_clean, how="left", on=["Mouse ID", "Timepoint"])
tumor_last_timepoint
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0       a203         45           67.973419                 2    Infubinol
# 1       a251         45           65.525743                 1    Infubinol
# 2       a262         45           70.717621                 4      Placebo
# 3       a275         45           62.999356                 3     Ceftamin
# 4       a366         30           63.440686                 1     Stelasyn
# ..       ...        ...                 ...               ...          ...
# 243     z435         10           48.710661                 0     Propriva
# 244     z578         45           30.638696                 0     Ramicane
# 245     z581         45           62.754451                 3    Infubinol
# 246     z795         45           65.741070                 3     Naftisol
# 247     z969         45           73.867845                 4     Naftisol
#
#         Sex  Age_months  Weight (g)
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments =["Capomulin", "Ramicane","Infubinol","Ceftamin"]

# Create empty list to fill with tumor vol data (for plotting)
Tumor_vol_data =[]

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
quartiles = tumor_last_timepoint.groupby("Drug Regimen")["Tumor Volume (mm3)"].quantile([0.25, 0.5, 0.75])

    # Locate the rows which contain mice on each drug and get the tumor volumes
for treatment in treatments:
    mice_on_drug_tumor = tumor_last_timepoint.loc[tumor_last_timepoint["Drug Regimen"] == treatment, "Tumor Volume (mm3)"]
    
    # add subset 
    Tumor_vol_data.append(mice_on_drug_tumor)
   
    
    # Determine outliers using upper and lower bounds
    
    lowerq = quartiles.loc[(treatment,0.25)]
    upperq = quartiles.loc[(treatment,0.75)]
    iqr = upperq-lowerq
    lower_bound = lowerq - (1.5 * iqr)
    upper_bound = upperq + (1.5 * iqr)
    outliers = mice_on_drug_tumor.loc[(mice_on_drug_tumor < lower_bound) | (mice_on_drug_tumor > upper_bound)]
    print(f"{treatment}'s potential outliers: {outliers}")
# Out:
# Capomulin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ramicane's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol's potential outliers: 31    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Ceftamin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
figure3, ax = plt.subplots(figsize=(7,5))
ax.boxplot(Tumor_vol_data,flierprops={"marker": "o", "markersize": 15, "markerfacecolor": "red"})
ax.set_xticklabels(treatments)
ax.set_ylabel("Final Tumor Volume (mm3)")
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin

mouse_l509 = study_data_complete.loc[study_data_complete["Mouse ID"] == "l509", ["Timepoint","Tumor Volume (mm3)"]]

#extracting data for  x_axis and y_axis

days = mouse_l509["Timepoint"]
Tumor_volume = mouse_l509["Tumor Volume (mm3)"]

#plotting

plt.plot(days, Tumor_volume, color = "blue")
plt.title("Capomulin treatment of mouse l509")
plt.xlabel("Timepoint (days)")
plt.ylabel("Tumor Volume (mm3)")
plt.show()

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen

mouse_on_Capomulin = study_data_complete.loc[study_data_complete["Drug Regimen"] == "Capomulin", ["Mouse ID","Weight (g)","Tumor Volume (mm3)"]]

#grouping by mouse ID to get weight and average tumor volume

mouse_on_Capomulin_grouped = mouse_on_Capomulin.groupby("Mouse ID")

#getting the first weight (assuming weight doesn't change over time for each mouse) and average tumor

weight = mouse_on_Capomulin_grouped["Weight (g)"].first()
tumor = mouse_on_Capomulin_grouped["Tumor Volume (mm3)"].mean()

#creating a scatter plot
plt.scatter(weight, tumor, marker="o", facecolor="blue", alpha = 0.7)
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen

correlation =st.pearsonr(weight, tumor)
print(f"The correlation between mouse weight and the average tumor volume is {round(correlation[0],2)}")


(slope, intercept, rvalue, pvalue, stderr) = st.linregress(weight, tumor)
regress_values = weight * slope + intercept
plt.scatter(weight, tumor, marker= "o", facecolor="blue", alpha = 0.7)
plt.plot(weight,regress_values,"r-")
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.show()
# Out:
# The correlation between mouse weight and the average tumor volume is 0.84
